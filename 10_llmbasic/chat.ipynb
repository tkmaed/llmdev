# %%
# メッセージの設定
message = "数学とはなんですか？"

# APIへリクエスト
stream = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    stream=True,
)

for chunk in stream:
    if chunk.choices:
        if chunk.choices[0].delta.content is not None:
            print(chunk.choices[0].delta.content, end="")
# Out:
# 数学とは、数量、構造、空間、変化などの概念を扱う科学の一分野です。数式や理論を用いて、現象や問題を分析し、解決するための方法を提供します。数学は抽象的な概念に基づきながらも、物理学や経済学、工学、コンピュータ科学などの実際の問題を解決するために広く応用されており、これらの分野と密接に関連しています。
#
# 具体的には、算数、代数、幾何学、微積分、統計学、確率論など、さまざまな分野が含まれます。数学は論理的思考や問題解決能力を養うための有力なツールでもあり、教育の重要な部分を占めています。

# %%
# トークンの選択度合い
message = """
AさんとBさんで会話してください。
A:あ、Bさんだ。
B:
"""

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    max_tokens=100,
    n=3,
    logit_bias = {74074:15, 11792:15, 29236:15, 8574:15}
)

# 結果を表示
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# --------------------
# B: ううううううううううううううううううううううううううううううううううううううううううううううううううううううううううううううううううううううううううううううううううううううううううううううううう
# --------------------
# B:ううん、なんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだ
# --------------------
# B: ううん、なんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなんだろうなん

# %%
import tiktoken
from tiktoken.core import Encoding

# OpenAI APIの特定のモデルに対応するトークナイザーを取得
encoding: Encoding = tiktoken.encoding_for_model(MODEL_NAME) # o200k_base

# テキストをトークンIDのリストに変換
tokens = encoding.encode("なんだろう")
tokens_count = len(tokens)

# トークンの長さとトークンIDを表示
print(f"{tokens_count=}")
print(f"{tokens=}")
# Out:
# tokens_count=4
# tokens=[74074, 11792, 29236, 8574]

# %%
# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ]
)

# レスポンスの表示
pprint(vars(response))

print(response.choices[0].message.content.strip())
# Out:
# {'_request_id': 'req_de840c2b1769400fb9b400fa4c7008d2',
#  'choices': [Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='言語モデルを使う上でのポイントはいくつかあります。以下に主なものを挙げます。\n\n1. **目的の明確化**:\n   - 何を達成したいのかを明確にしましょう。例えば、文章生成、要約、質問応答など、具体的な目的を設定することで、モデルの使い方が変わります。\n\n2. **入力の工夫**:\n   - モデルに与える入力（プロンプト）を工夫することで、出力の質が大きく変わります。具体的かつ明確な指示を与えることが重要です。\n\n3. **文脈の提供**:\n   - モデルが理解しやすいように、必要な文脈を提供すると良い結果が得られやすいです。前提となる情報や条件を明示することが大切です。\n\n4. **出力の確認と編集**:\n   - モデルからの出力は必ずしも正確ではないため、事実確認や適宜の編集が必要です。自然言語処理モデルは、学習データに基づいた予測を行うため、偏りや誤りが含まれる可能性があります。\n\n5. **バランスを考える**:\n   - 自動生成されたコンテンツと人間の判断や介入のバランスを考慮しましょう。完全に自動化することが常に最善ではないこともあります。\n\n6. **倫理的配慮**:\n   - 特に社会的影響を考慮し、差別的な表現や誤解を招く内容に注意することが重要です。出力内容が不適切でないか常にチェックしましょう。\n\n7. **モデルの特性理解**:\n   - 使用する言語モデルの特性や限界を理解すること。例えば、文脈の長さ、特定のトピックに対する精度、反応のスタイルなどについて理解を深めることが、大きな効果をもたらします。\n\nこれらのポイントを念頭に置きながら、言語モデルを効果的に利用していくことが重要です。', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))],
#  'created': 1771380439,
#  'id': 'chatcmpl-DARGBPaTAs3JIaSF6AJFCZFgxEvWU',
#  'model': 'gpt-4o-mini-2024-07-18',
#  'object': 'chat.completion',
#  'service_tier': 'default',
#  'system_fingerprint': 'fp_373a14eb6f',
#  'usage': CompletionUsage(completion_tokens=506, prompt_tokens=18, total_tokens=524, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))}

# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from openai import OpenAI
from pprint import pprint

# 環境変数の取得
load_dotenv("../.env")

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"

# %%
principal = int(input("元金を入力してください: "))
annual_interest_rate = float(input("年利を入力してください: ")) / 100
for i in range(10):
    principal = principal + principal * annual_interest_rate
print(f"10年後の金額: {principal:.2f}")
# Out:
# 10年後の金額: 1628.89

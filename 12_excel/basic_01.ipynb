# %%
# 1. Excelファイルを読み込む
df = pd.read_excel('サンプルデータ.xlsx', sheet_name='アンケート')
# データフレームを表示して確認
df.head()
# Out:
#                                                アンケート
# 0  「使った瞬間、髪がしっとりサラサラになり驚きました。香りも強すぎずリラックスできる香りで気に...
# 1  「洗い上がりはスッキリするのに、髪が全然きしまず指通りが良くなりました！乾燥しがちな髪質です...
# 2  「香りが少し甘めで、好みが分かれそうです。個人的には好きですが、甘い香りが苦手な方には少し強...
# 3  「ボトルのデザインがシンプルでおしゃれなので、バスルームが映える感じがします。使用感も良くて...
# 4  「使い始めてから頭皮のかゆみが減りました。敏感肌なので合わないシャンプーが多いのですが、これ...

# %%
# 2. データをLLM用にテキスト形式に変換
# データフレーム全体を文字列に変換
sales_data_text = df.astype(str)
prompt_text = f"売上データ:\n{sales_data_text}\nこの売上データの問題点を分析してください。"
# 表示して確認
print(prompt_text)
print()

# 3. OpenAI APIの呼び出し

# 役割を設定
role = "あなたはマーケティング分野に精通したデータサイエンティストです。企業の成長をサポートするために、効果的なインサイトを提供します。"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "system", "content": role},
        {"role": "user", "content": prompt_text},
    ],
)

# LLMからの回答を表示
for choice in response.choices:
    print(choice.message.content.strip())

# 4. 分析結果をデータフレームに変換
result_list = response.choices[0].message.content.strip().split("\n")
df_out = pd.DataFrame(result_list, columns=['結果'])
print(df_out)

# 5. 結果をExcelファイルに保存
df_out.to_excel("売上データ分析結果.xlsx", index=False)
# Out:
# 売上データ:
#     カテゴリー 商品コード      商品名         売上日    単価   数量    原価
# 0      食品  1001      りんご  2023-01-01   200   50   120
# 1      食品  1002      バナナ  2023-01-01   150  100    80
# 2      食品  1003       牛乳  2023-01-02   180   80   100
# 3      衣服  2001     Tシャツ  2023-01-02  1500   20   800
# 4      衣服  2002     ジーンズ  2023-01-03  5000   10  2500
# ..    ...   ...      ...         ...   ...  ...   ...
# 235    衣服  2077   レインパンツ  2023-04-28  2000   18  1000
# 236    食品  1085      ザクロ  2023-04-29   600   40   300
# 237   日用品  3077    バスブラシ  2023-04-29   400   60   200
# 238    衣服  2078  レインシューズ  2023-04-30  2500   15  1250
# 239    食品  1086    ココナッツ  2023-04-30   300   80   150
#
# [240 rows x 7 columns]
# この売上データの問題点を分析してください。
#
# この売上データの問題点を分析するために、いくつかの観点から見ていきます。
#
# ### 1. データの整合性
# - **欠損値**: すべての必要なカラム（商品コード、商品名、売上日、単価、数量、原価）が埋まっているか確認する必要があります。欠損値は分析の精度に影響を及ぼします。
# - **重複データ**: 同じ売上が記録されていないか、重複したエントリがあるかも確認する必要があります。これは集計や分析に影響します。
#
# ### 2. データの一貫性
# - **日時のフォーマット**: 売上日のフォーマット（YYYY-MM-DD）が一貫しているか確認します。一貫性がない場合、時間的な分析が困難になります。
# - **商品名・商品コードの統一性**: 商品名や商品コードが正しくかつ一貫して登録されているか確認します（例: 「バナナ」と「ばなな」のように異なる表記が存在しないか）。
#
# ### 3. 価格設定の妥当性
# - **単価と原価**: 単価が常に原価より高く設定されているかを確認します。単価が原価以下のデータは赤字を示唆し、経営に支障をきたす可能性があります。また、単価や原価に異常値がないかも重要です。
#
# ### 4. 時間的な分析
# - **売上の季節性やトレンド**: 売上日ごとのデータを用いて、売上のトレンドや季節性を分析することが重要です。例えば、特定の季節や月に売上が増減する傾向があるかを確認します。
#
# ### 5. カテゴリー別の比較
# - **カテゴリーごとの売上分析**: カテゴリー（食品、衣服、日用品など）によって売上の分布やパフォーマンスが異なるかを分析する必要があります。これにより、どのカテゴリーが高いパフォーマンスを示しているかを把握できます。
#
# ### 6. 在庫管理
# - **販売数量と在庫**: 販売数量が在庫レベルに基づいて適切であるか確認します。在庫が不足している商品や、逆に過剰在庫の危険がある場合も分析対象となります。
#
# ### 7. 外部要因
# - **プロモーションや競争**: シーズンごとのプロモーションや競争の影響も考慮すべきです。特定の期間にプロモーションを行ったか、競争が激しい期間があったかを確認します。
#
# これらの点を順番に分析し、問題点を特定することで、売上データから価値のあるインサイトを引き出すことが可能です。データの質が向上すれば、より良い意思決定と戦略的計画が実施できるようになります。
#                                                    結果
# 0                この売上データの問題点を分析するために、いくつかの観点から見ていきます。
# 1
# 2                                      ### 1. データの整合性
# 3   - **欠損値**: すべての必要なカラム（商品コード、商品名、売上日、単価、数量、原価）が...
# 4   - **重複データ**: 同じ売上が記録されていないか、重複したエントリがあるかも確認する必...
# 5
# 6                                      ### 2. データの一貫性
# 7   - **日時のフォーマット**: 売上日のフォーマット（YYYY-MM-DD）が一貫している...
# 8   - **商品名・商品コードの統一性**: 商品名や商品コードが正しくかつ一貫して登録されてい...
# 9
# 10                                    ### 3. 価格設定の妥当性
# 11  - **単価と原価**: 単価が常に原価より高く設定されているかを確認します。単価が原価以下...
# 12
# 13                                      ### 4. 時間的な分析
# 14  - **売上の季節性やトレンド**: 売上日ごとのデータを用いて、売上のトレンドや季節性を分...
# 15
# 16                                   ### 5. カテゴリー別の比較
# 17  - **カテゴリーごとの売上分析**: カテゴリー（食品、衣服、日用品など）によって売上の分...
# 18
# 19                                        ### 6. 在庫管理
# 20  - **販売数量と在庫**: 販売数量が在庫レベルに基づいて適切であるか確認します。在庫が不...
# 21
# 22                                        ### 7. 外部要因
# 23  - **プロモーションや競争**: シーズンごとのプロモーションや競争の影響も考慮すべきです...
# 24
# 25  これらの点を順番に分析し、問題点を特定することで、売上データから価値のあるインサイトを引き出...

# %%
# 1. Excelファイルを読み込む
df = pd.read_excel('サンプルデータ.xlsx', sheet_name='売上データ')
# データフレームを表示して確認
df.head()
# Out:
#   カテゴリー  商品コード   商品名        売上日    単価   数量    原価
# 0    食品   1001   りんご 2023-01-01   200   50   120
# 1    食品   1002   バナナ 2023-01-01   150  100    80
# 2    食品   1003    牛乳 2023-01-02   180   80   100
# 3    衣服   2001  Tシャツ 2023-01-02  1500   20   800
# 4    衣服   2002  ジーンズ 2023-01-03  5000   10  2500

# %%
import pandas as pd

# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from openai import OpenAI

# 環境変数の取得
load_dotenv()

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"
